# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams.update({'font.size': 20, 'figure.figsize': (10, 8)}) # set font and plot size to be larger

# %%
data = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2]
}

purchases = pd.DataFrame(data)
purchases
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
purchases = pd.DataFrame(data, index=['June', 'Robert', 'Lily', 'David'])
purchases
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
purchases.loc['June']
# Out:
# apples     3
# oranges    0
# Name: June, dtype: int64

# %%
df = pd.read_csv('data/NHTS/hhpub.csv', index_col=0)
df
# Out:
#           TRAVDAY  SAMPSTRAT  HOMEOWN  HHSIZE  HHVEHCNT  HHFAMINC  PC  SPHONE  \
# HOUSEID
# 30000007        2          3        1       3         5         7   2       1
# 30000008        5          2        1       2         4         8   1       1
# 30000012        5          3        1       1         2        10   1       1
# 30000019        5          3        1       2         2         3   1       5
# 30000029        3          3        1       2         2         5   2       5
# ...           ...        ...      ...     ...       ...       ...  ..     ...
# 40794291        7          3        1       1         1         9   1       5
# 40794293        2          4        1       2         3         6   1       1
# 40794294        5          2        1       2         2        10   1       1
# 40794301        2          3        1       7         5         6   1       5
# 50515573        3          1        1       1         0        10   1       1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129696 entries, 30000007 to 50515573
# Data columns (total 57 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   TRAVDAY     129696 non-null  int64
#  1   SAMPSTRAT   129696 non-null  int64
#  2   HOMEOWN     129696 non-null  int64
#  3   HHSIZE      129696 non-null  int64
#  4   HHVEHCNT    129696 non-null  int64
#  5   HHFAMINC    129696 non-null  int64
#  6   PC          129696 non-null  int64
#  7   SPHONE      129696 non-null  int64
#  8   TAB         129696 non-null  int64
#  9   WALK        129696 non-null  int64
#  10  BIKE        129696 non-null  int64
#  11  CAR         129696 non-null  int64
#  12  TAXI        129696 non-null  int64
#  13  BUS         129696 non-null  int64
#  14  TRAIN       129696 non-null  int64
#  15  PARA        129696 non-null  int64
#  16  PRICE       129696 non-null  int64
#  17  PLACE       129696 non-null  int64
# ...

# %%
df.shape
# Out:
# (129696, 57)

# %%
df.isnull().sum()
# Out:
# TRAVDAY       0
# SAMPSTRAT     0
# HOMEOWN       0
# HHSIZE        0
# HHVEHCNT      0
# HHFAMINC      0
# PC            0
# SPHONE        0
# TAB           0
# WALK          0
# BIKE          0
# CAR           0
# TAXI          0
# BUS           0
# TRAIN         0
# PARA          0
# PRICE         0
# PLACE         0
# WALK2SAVE     0
# BIKE2SAVE     0
# PTRANS        0
# HHRELATD      0
# DRVRCNT       0
# CNTTDHH       0
# HHSTATE       0
# HHSTFIPS      0
# NUMADLT       0
# YOUNGCHILD    0
# WRKCOUNT      0
# TDAYDATE      0
# HHRESP        0
# LIF_CYC       0
# MSACAT        0
# MSASIZE       0
# RAIL          0
# URBAN         0
# URBANSIZE     0
# URBRUR        0
# SCRESP        0
# CENSUS_D      0
# CENSUS_R      0
# CDIVMSAR      0
# HH_RACE       0
# HH_HISP       0
# HH_CBSA       0
# RESP_CNT      0
# WEBUSE17      0
# SMPLSRCE      0
# WTHHFIN       0
# HBHUR         0
# HTHTNRNT      0
# HTPPOPDN      0
# HTRESDN       0
# HTEEMPDN      0
# HBHTNRNT      0
# ...

# %%
df.describe()
# Out:
#              TRAVDAY      SAMPSTRAT        HOMEOWN         HHSIZE  \
# count  129696.000000  129696.000000  129696.000000  129696.000000
# mean        3.996600       2.593665       1.922534       2.128786
# std         1.881475       0.909083       8.109815       1.166556
# min         1.000000       1.000000      -8.000000       1.000000
# 25%         2.000000       2.000000       1.000000       1.000000
# 50%         4.000000       3.000000       1.000000       2.000000
# 75%         6.000000       3.000000       1.000000       3.000000
# max         7.000000       4.000000      97.000000      13.000000
#
#             HHVEHCNT       HHFAMINC             PC         SPHONE  \
# count  129696.000000  129696.000000  129696.000000  129696.000000
# mean        1.974733       5.527665       1.484888       1.666960
# std         1.177825       3.503986       1.912263       2.432491
# min         0.000000      -9.000000      -9.000000      -9.000000
# ...

# %%
df['PC'].value_counts()
# Out:
#  1    90995
#  2    14551
#  5    12679
#  3     6110
#  4     3000
# -9     2355
# -7        5
# -8        1
# Name: PC, dtype: int64

# %%
df.corr().head()
# Out:
#             TRAVDAY  SAMPSTRAT   HOMEOWN    HHSIZE  HHVEHCNT  HHFAMINC  \
# TRAVDAY    1.000000   0.002172 -0.000704  0.003818  0.001906  0.000940
# SAMPSTRAT  0.002172   1.000000  0.014776 -0.034339  0.081518 -0.140527
# HOMEOWN   -0.000704   0.014776  1.000000 -0.002592 -0.037442 -0.056592
# HHSIZE     0.003818  -0.034339 -0.002592  1.000000  0.401171  0.229108
# HHVEHCNT   0.001906   0.081518 -0.037442  0.401171  1.000000  0.292816
#
#                  PC    SPHONE       TAB      WALK  ...  WEBUSE17  SMPLSRCE  \
# TRAVDAY    0.000420  0.001853 -0.001486  0.003405  ...  0.002007  0.003498
# SAMPSTRAT  0.065880  0.058720  0.028340 -0.003908  ...  0.068824  0.069072
# HOMEOWN    0.016973  0.008181  0.007324 -0.004355  ...  0.014785 -0.000049
# HHSIZE    -0.063353 -0.093738 -0.050485  0.077418  ... -0.119789  0.002904
# HHVEHCNT  -0.076337 -0.050186 -0.024200  0.077529  ... -0.111646  0.005822
#
#             WTHHFIN  HTHTNRNT  HTPPOPDN   HTRESDN  HTEEMPDN  HBHTNRNT  \
# ...

# %%
condition = df['HHSIZE'] < 4
df[condition]
# Out:
#           TRAVDAY  SAMPSTRAT  HOMEOWN  HHSIZE  HHVEHCNT  HHFAMINC  PC  SPHONE  \
# HOUSEID
# 30000007        2          3        1       3         5         7   2       1
# 30000008        5          2        1       2         4         8   1       1
# 30000012        5          3        1       1         2        10   1       1
# 30000019        5          3        1       2         2         3   1       5
# 30000029        3          3        1       2         2         5   2       5
# ...           ...        ...      ...     ...       ...       ...  ..     ...
# 40794249        2          3        2       1         0         2   5       5
# 40794291        7          3        1       1         1         9   1       5
# 40794293        2          4        1       2         3         6   1       1
# 40794294        5          2        1       2         2        10   1       1
# 50515573        3          1        1       1         0        10   1       1
#
# ...

# %%
df.head()
df.groupby('HHSIZE')['TRAVDAY'].mean()
#df.groupby('HHSIZE').mean()
# Out:
# HHSIZE
# 1     3.987719
# 2     3.999116
# 3     4.002758
# 4     3.988110
# 5     4.028162
# 6     4.068348
# 7     4.015464
# 8     4.111111
# 9     4.098039
# 10    3.763158
# 11    4.750000
# 12    3.500000
# 13    1.000000
# Name: TRAVDAY, dtype: float64

# %%
df.columns = [col.lower() for col in df]
df.plot(kind='scatter', x='hhsize', y='hhfaminc', title='huh');

# %%
df['hhsize'].plot(kind='hist',title='hhsize dist')

# %%
df['hhsize'].plot(kind='box');

# %%
inc = df[['hhfaminc']]
inc = inc[inc < 0]

# %%
inc['hhfaminc'].value_counts()
# Out:
# -7.0    3540
# -8.0     801
# -9.0      35
# Name: hhfaminc, dtype: int64
